# %% [markdown]
# ## Week 1 Homework
#
# In this homework we'll prepare the environment
# and practice with Docker and SQL
#
#
# ## Question 1. Knowing docker tags
#
# Run the command to get information on Docker
#
# ```docker --help```
#
# Now run the command to get help on the "docker build" command
#
# Which tag has the following text? - *Write the image ID to the file*
#
# - `--imageid string`
# - `--iidfile string`
# - `--idimage string`
# - `--idfile string`
#
# ![Alt text](images/docker-q1.png "a title")

# %% [markdown]
# ## Question 2. Understanding docker first run
#
# Run docker with the python:3.9 image in an interactive mode and the entrypoint of bash.
# Now check the python modules that are installed ( use pip list).
# How many python packages/modules are installed?
#
# - 1
# - 6
# - 3
# - 7
#
# ![Alt text](images/python_files.png "a title")

# %% [markdown]
# ## Question 3. Count records
#
# How many taxi trips were totally made on January 15?
#
# Tip: started and finished on 2019-01-15.
#
# Remember that `lpep_pickup_datetime` and `lpep_dropoff_datetime` columns are in the format timestamp (date and hour+min+sec) and not in date.
#
# - 20689
# - 20530
# - 17630
# - 21090

# %%
# !wget wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-01.csv.gz
# Out:
# --2023-01-29 12:02:30--  http://wget/
# Resolving wget (wget)... failed: nodename nor servname provided, or not known.
# wget: unable to resolve host address ‘wget’
# --2023-01-29 12:02:30--  https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-01.csv.gz
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('green_tripdata_2019-01.csv.gz')

# %%
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              2  2018-12-21 15:17:29   2018-12-21 15:18:57
# 1              2  2019-01-01 00:10:16   2019-01-01 00:16:32
# 2              2  2019-01-01 00:27:11   2019-01-01 00:31:38
# 3              2  2019-01-01 00:46:20   2019-01-01 01:04:54
# 4              2  2019-01-01 00:19:06   2019-01-01 00:39:43
# ...          ...                  ...                   ...
# 630913         2  2019-01-31 23:08:27   2019-01-31 23:22:59
# 630914         2  2019-01-31 23:21:26   2019-01-31 23:23:05
# 630915         2  2019-01-31 23:30:05   2019-01-31 23:36:14
# 630916         2  2019-01-31 23:59:58   2019-02-01 00:04:18
# 630917         2  2019-01-31 23:18:22   2019-01-31 23:26:06
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N           1           264           264
# 1                       N           1            97            49
# ...

# %%
df.dtypes
# Out:
# VendorID                   int64
# lpep_pickup_datetime      object
# lpep_dropoff_datetime     object
# store_and_fwd_flag        object
# RatecodeID                 int64
# PULocationID               int64
# DOLocationID               int64
# passenger_count            int64
# trip_distance            float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# ehail_fee                float64
# improvement_surcharge    float64
# total_amount             float64
# payment_type               int64
# trip_type                  int64
# congestion_surcharge     float64
# dtype: object

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

# %%
df.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime            object
# store_and_fwd_flag               object
# RatecodeID                        int64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                   int64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                      int64
# trip_type                         int64
# congestion_surcharge            float64
# dtype: object

# %%
df["date_pickup"] = pd.to_datetime(df["lpep_pickup_datetime"]).dt.date
df["date_dropoff"] = pd.to_datetime(df["lpep_dropoff_datetime"]).dt.date

# %%
df.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime            object
# store_and_fwd_flag               object
# RatecodeID                        int64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                   int64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                      int64
# trip_type                         int64
# congestion_surcharge            float64
# date_pickup                      object
# date_dropoff                     object
# dtype: object

# %%
df.date_pickup = pd.to_datetime(df.date_pickup)
df.date_dropoff = pd.to_datetime(df.date_dropoff)

# %%
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              2  2018-12-21 15:17:29   2018-12-21 15:18:57
# 1              2  2019-01-01 00:10:16   2019-01-01 00:16:32
# 2              2  2019-01-01 00:27:11   2019-01-01 00:31:38
# 3              2  2019-01-01 00:46:20   2019-01-01 01:04:54
# 4              2  2019-01-01 00:19:06   2019-01-01 00:39:43
# ...          ...                  ...                   ...
# 630913         2  2019-01-31 23:08:27   2019-01-31 23:22:59
# 630914         2  2019-01-31 23:21:26   2019-01-31 23:23:05
# 630915         2  2019-01-31 23:30:05   2019-01-31 23:36:14
# 630916         2  2019-01-31 23:59:58   2019-02-01 00:04:18
# 630917         2  2019-01-31 23:18:22   2019-01-31 23:26:06
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N           1           264           264
# 1                       N           1            97            49
# ...

# %%
df_filtered = df[(df['date_pickup'].dt.strftime('%Y-%m-%d') == '2019-01-15')]

# %%
df_filtered
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 272684         2  2019-01-15 15:33:43   2019-01-15 15:33:50
# 275421         2  2019-01-15 16:50:12   2019-01-15 17:23:03
# 276753         2  2019-01-15 17:44:00   2019-01-15 18:03:10
# 278806         2  2019-01-15 20:02:24   2019-01-15 20:17:52
# 279998         2  2019-01-15 00:00:45   2019-01-15 00:07:05
# ...          ...                  ...                   ...
# 301223         2  2019-01-15 22:29:47   2019-01-15 22:39:48
# 301247         2  2019-01-15 23:59:16   2019-01-16 00:05:11
# 301258         2  2019-01-15 22:56:18   2019-01-15 23:43:35
# 301411         2  2019-01-15 22:18:09   2019-01-15 22:25:53
# 301517         2  2019-01-15 21:52:54   2019-01-15 21:55:14
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 272684                  N           5           195           195
# 275421                  N           1           195            17
# ...

# %% [markdown]
# ## Question 4. Largest trip for each day
#
# Which was the day with the largest trip distance
# Use the pick up time for your calculations.
#
# - 2019-01-18
# - 2019-01-28
# - 2019-01-15
# - 2019-01-10

# %%
max(df["trip_distance"])
# Out:
# 117.99

# %%
df.loc[df["trip_distance"] == 117.99]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 297377         2  2019-01-15 19:27:58   2019-01-15 22:59:01
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 297377                  N           1           221           265
#
#         passenger_count  trip_distance  fare_amount  ...  tip_amount  \
# 297377                1         117.99        323.0  ...         0.0
#
#         tolls_amount  ehail_fee  improvement_surcharge  total_amount  \
# 297377          10.5        NaN                    0.3         339.2
#
#         payment_type  trip_type  congestion_surcharge  date_pickup  \
# 297377             2          1                   NaN   2019-01-15
#
#         date_dropoff
# 297377    2019-01-15
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Question 5. The number of passengers
#
# In 2019-01-01 how many trips had 2 and 3 passengers?
#
# - 2: 1282 ; 3: 266
# - 2: 1532 ; 3: 126
# - 2: 1282 ; 3: 254
# - 2: 1282 ; 3: 274

# %%
df_filtered = df[(df['date_pickup'].dt.strftime('%Y-%m-%d') == '2019-01-01')]

# %%
df_filtered.loc[df_filtered["passenger_count"] == 2]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 1             2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2             2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3             2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 11            2  2019-01-01 00:13:48   2019-01-01 00:21:00                  N
# 32            2  2019-01-01 00:40:23   2019-01-01 00:56:12                  N
# ...         ...                  ...                   ...                ...
# 14971         2  2019-01-01 23:33:40   2019-01-01 23:56:47                  N
# 14996         2  2019-01-01 23:10:16   2019-01-01 23:18:13                  N
# 14997         2  2019-01-01 23:34:15   2019-01-01 23:44:05                  N
# 15029         1  2019-01-01 23:08:14   2019-01-01 23:12:59                  N
# 15032         1  2019-01-01 23:42:48   2019-01-01 23:47:44                  N
#
# ...

# %%
df_filtered.loc[df_filtered["passenger_count"] == 3]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 31            2  2019-01-01 00:08:07   2019-01-01 00:18:36                  N
# 40            2  2019-01-01 00:31:28   2019-01-01 00:57:27                  N
# 67            2  2019-01-01 00:39:51   2019-01-01 00:43:05                  N
# 149           2  2019-01-01 00:35:40   2019-01-01 01:20:13                  N
# 185           2  2019-01-01 00:09:09   2019-01-01 01:04:26                  N
# ...         ...                  ...                   ...                ...
# 14666         1  2019-01-01 22:15:36   2019-01-01 22:28:07                  N
# 14753         1  2019-01-01 23:46:40   2019-01-01 23:53:04                  N
# 14830         2  2019-01-01 23:20:47   2019-01-01 23:28:04                  N
# 14959         2  2019-01-01 23:16:50   2019-01-01 23:24:38                  N
# 14970         2  2019-01-01 23:34:57   2019-01-01 23:45:51                  N
#
# ...

# %%
# !wget https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Out:
# --2023-01-29 12:02:34--  https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.202.152, 52.216.210.64, 52.216.222.144, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.202.152|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12322 (12K) [application/octet-stream]
# Saving to: ‘taxi+_zone_lookup.csv.1’
#
# taxi+_zone_lookup.c 100%[===================>]  12,03K  --.-KB/s    in 0,003s
#
# 2023-01-29 12:02:35 (4,04 MB/s) - ‘taxi+_zone_lookup.csv.1’ saved [12322/12322]

# %% [markdown]
# ## Question 6. Largest tip
#
# For the passengers picked up in the Astoria Zone which was the drop off zone that had the largest tip?
# We want the name of the zone, not the id.
#
# Note: it's not a typo, it's `tip` , not `trip`
#
# - Central Park
# - Jamaica
# - South Ozone Park
# - Long Island City/Queens Plaza

# %%
df_zone = pd.read_csv("taxi+_zone_lookup.csv")

# %%
df_zone
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
df_zone.loc[df_zone["Zone"] == "Astoria"]
# Out:
#    LocationID Borough     Zone service_zone
# 6           7  Queens  Astoria    Boro Zone

# %%
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              2  2018-12-21 15:17:29   2018-12-21 15:18:57
# 1              2  2019-01-01 00:10:16   2019-01-01 00:16:32
# 2              2  2019-01-01 00:27:11   2019-01-01 00:31:38
# 3              2  2019-01-01 00:46:20   2019-01-01 01:04:54
# 4              2  2019-01-01 00:19:06   2019-01-01 00:39:43
# ...          ...                  ...                   ...
# 630913         2  2019-01-31 23:08:27   2019-01-31 23:22:59
# 630914         2  2019-01-31 23:21:26   2019-01-31 23:23:05
# 630915         2  2019-01-31 23:30:05   2019-01-31 23:36:14
# 630916         2  2019-01-31 23:59:58   2019-02-01 00:04:18
# 630917         2  2019-01-31 23:18:22   2019-01-31 23:26:06
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N           1           264           264
# 1                       N           1            97            49
# ...

# %%
max(df.loc[df["PULocationID"] == 7]["tip_amount"])
# Out:
# 88.0

# %%
df_temp = df.loc[df["PULocationID"] == 7]

# %%
df_temp
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 23             2  2019-01-01 00:39:09   2019-01-01 00:42:32
# 25             1  2019-01-01 00:35:52   2019-01-01 00:40:00
# 26             1  2019-01-01 00:48:27   2019-01-01 00:55:49
# 96             2  2019-01-01 00:21:28   2019-01-01 00:48:15
# 100            2  2019-01-01 00:53:11   2019-01-01 00:57:04
# ...          ...                  ...                   ...
# 630794         2  2019-02-01 00:24:02   2019-02-01 00:28:09
# 630821         2  2019-01-31 23:57:22   2019-02-01 00:05:31
# 630824         2  2019-01-31 23:29:43   2019-01-31 23:36:19
# 630825         2  2019-01-31 23:43:47   2019-01-31 23:48:35
# 630833         1  2019-01-31 23:55:36   2019-01-31 23:59:21
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 23                      N           1             7             7
# 25                      N           1             7           260
# ...

# %%
df_temp.loc[df_temp["tip_amount"] == 88]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 506162         2  2019-01-26 00:46:06   2019-01-26 00:50:10
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 506162                  N           1             7           146
#
#         passenger_count  trip_distance  fare_amount  ...  tip_amount  \
# 506162                1           0.92          5.5  ...        88.0
#
#         tolls_amount  ehail_fee  improvement_surcharge  total_amount  \
# 506162           0.0        NaN                    0.3          94.8
#
#         payment_type  trip_type  congestion_surcharge  date_pickup  \
# 506162             1          1                   NaN   2019-01-26
#
#         date_dropoff
# 506162    2019-01-26
#
# [1 rows x 22 columns]

# %%
df_zone.loc[df_zone["LocationID"] == 146]
# Out:
#      LocationID Borough                           Zone service_zone
# 145         146  Queens  Long Island City/Queens Plaza    Boro Zone
